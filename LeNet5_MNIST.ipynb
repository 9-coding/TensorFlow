# %% [markdown]
# <a href="https://colab.research.google.com/github/9-coding/TensorFlow/blob/main/LeNet5_MNIST.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import tensorflow as tf
import tensorflow.keras.datasets as ds

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dropout, Dense
from tensorflow.keras.optimizers import Adam

# 데이터 준비
(x_train, y_train),(x_test, y_test)=ds.mnist.load_data()
# 28x28을 784로 펼침.
x_train=x_train.reshape(60000, 28, 28, 1)
x_test=x_test.reshape(10000, 28, 28, 1)
# 원래 데이터형 unit8을 실수 연산을 위해 float32로 변환, [0,255] 범위를 [0,1]로.
x_train=x_train.astype(np.float32)/255.0
x_test=x_test.astype(np.float32)/255.0
# 0~9 사이의 정수로 표현된 것을 one-hot-vector로 변환.
y_train=tf.keras.utils.to_categorical(y_train,10)
y_test=tf.keras.utils.to_categorical(y_test,10)

# LeNet-5 모델 구성
cnn=Sequential()
cnn.add(Conv2D(6, (5,5), padding='same', activation='relu', input_shape=(28,28,1)))
cnn.add(MaxPooling2D(pool_size=(2,2), strides=2))
cnn.add(Conv2D(16, (5,5), padding='valid', activation='relu'))
cnn.add(MaxPooling2D(pool_size=(2,2), strides=2))
cnn.add(Conv2D(120, (5,5), padding='valid', activation='relu'))
cnn.add(Flatten())
cnn.add(Dense(units=84, activation='relu'))
cnn.add(Dense(units=10, activation='softmax'))

# 학습
# compile과 fit 동시에 사용.
cnn.compile(loss='categorical_crossentropy', optimizer=Adam(learning_rate=0.001), metrics=['accuracy'])
cnn.fit(x_train, y_train, batch_size=128, epochs=50, validation_data=(x_test, y_test), verbose=2)

# 예측 및 성능 측정
res=cnn.evaluate(x_test,y_test, verbose=0)
print('정확도=', res[1]*100)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 [==============================] - 0s 0us/step
# Epoch 1/50
# 469/469 - 13s - loss: 0.3160 - accuracy: 0.9034 - val_loss: 0.0741 - val_accuracy: 0.9780 - 13s/epoch - 27ms/step
# Epoch 2/50
# 469/469 - 2s - loss: 0.0800 - accuracy: 0.9758 - val_loss: 0.0482 - val_accuracy: 0.9844 - 2s/epoch - 5ms/step
# Epoch 3/50
# 469/469 - 2s - loss: 0.0571 - accuracy: 0.9827 - val_loss: 0.0409 - val_accuracy: 0.9866 - 2s/epoch - 4ms/step
# Epoch 4/50
# 469/469 - 2s - loss: 0.0457 - accuracy: 0.9861 - val_loss: 0.0348 - val_accuracy: 0.9882 - 2s/epoch - 4ms/step
# Epoch 5/50
# 469/469 - 2s - loss: 0.0361 - accuracy: 0.9882 - val_loss: 0.0354 - val_accuracy: 0.9891 - 2s/epoch - 4ms/step
# Epoch 6/50
# 469/469 - 2s - loss: 0.0322 - accuracy: 0.9897 - val_loss: 0.0298 - val_accuracy: 0.9897 - 2s/epoch - 4ms/step
# Epoch 7/50
# 469/469 - 2s - loss: 0.0270 - accuracy: 0.9916 - val_loss: 0.0364 - val_accuracy: 0.9874 - 2s/epoch - 4ms/step
# Epoch 8/50
# 469/469 - 2s - loss: 0.0227 - accuracy: 0.9929 - val_loss: 0.0334 - val_accuracy: 0.9887 - 2s/epoch - 4ms/step
# Epoch 9/50
# 469/469 - 2s - loss: 0.0208 - accuracy: 0.9932 - val_loss: 0.0303 - val_accuracy: 0.9905 - 2s/epoch - 4ms/step
# Epoch 10/50
# 469/469 - 2s - loss: 0.0180 - accuracy: 0.9941 - val_loss: 0.0286 - val_accuracy: 0.9919 - 2s/epoch - 4ms/step
# Epoch 11/50
# 469/469 - 2s - loss: 0.0167 - accuracy: 0.9946 - val_loss: 0.0331 - val_accuracy: 0.9897 - 2s/epoch - 4ms/step
# Epoch 12/50
# 469/469 - 2s - loss: 0.0152 - accuracy: 0.9949 - val_loss: 0.0291 - val_accuracy: 0.9914 - 2s/epoch - 4ms/step
# Epoch 13/50
# 469/469 - 2s - loss: 0.0123 - accuracy: 0.9960 - val_loss: 0.0312 - val_accuracy: 0.9900 - 2s/epoch - 4ms/step
# Epoch 14/50
# 469/469 - 2s - loss: 0.0105 - accuracy: 0.9965 - val_loss: 0.0354 - val_accuracy: 0.9896 - 2s/epoch - 5ms/step
# Epoch 15/50
# 469/469 - 2s - loss: 0.0109 - accuracy: 0.9963 - val_loss: 0.0397 - val_accuracy: 0.9890 - 2s/epoch - 4ms/step
# Epoch 16/50
# 469/469 - 2s - loss: 0.0103 - accuracy: 0.9965 - val_loss: 0.0423 - val_accuracy: 0.9898 - 2s/epoch - 4ms/step
# Epoch 17/50
# 469/469 - 2s - loss: 0.0073 - accuracy: 0.9977 - val_loss: 0.0397 - val_accuracy: 0.9896 - 2s/epoch - 4ms/step
# Epoch 18/50
# 469/469 - 2s - loss: 0.0097 - accuracy: 0.9965 - val_loss: 0.0365 - val_accuracy: 0.9911 - 2s/epoch - 4ms/step
# Epoch 19/50
# 469/469 - 2s - loss: 0.0079 - accuracy: 0.9973 - val_loss: 0.0401 - val_accuracy: 0.9904 - 2s/epoch - 4ms/step
# Epoch 20/50
# 469/469 - 2s - loss: 0.0077 - accuracy: 0.9971 - val_loss: 0.0383 - val_accuracy: 0.9895 - 2s/epoch - 5ms/step
# Epoch 21/50
# 469/469 - 2s - loss: 0.0061 - accuracy: 0.9979 - val_loss: 0.0357 - val_accuracy: 0.9914 - 2s/epoch - 4ms/step
# Epoch 22/50
# 469/469 - 2s - loss: 0.0063 - accuracy: 0.9979 - val_loss: 0.0424 - val_accuracy: 0.9910 - 2s/epoch - 4ms/step
# Epoch 23/50
# 469/469 - 2s - loss: 0.0064 - accuracy: 0.9976 - val_loss: 0.0445 - val_accuracy: 0.9899 - 2s/epoch - 4ms/step
# Epoch 24/50
# 469/469 - 2s - loss: 0.0058 - accuracy: 0.9979 - val_loss: 0.0450 - val_accuracy: 0.9903 - 2s/epoch - 4ms/step
# Epoch 25/50
# 469/469 - 2s - loss: 0.0048 - accuracy: 0.9984 - val_loss: 0.0502 - val_accuracy: 0.9889 - 2s/epoch - 4ms/step
# Epoch 26/50
# 469/469 - 2s - loss: 0.0048 - accuracy: 0.9983 - val_loss: 0.0406 - val_accuracy: 0.9910 - 2s/epoch - 5ms/step
# Epoch 27/50
# 469/469 - 2s - loss: 0.0056 - accuracy: 0.9980 - val_loss: 0.0507 - val_accuracy: 0.9900 - 2s/epoch - 4ms/step
# Epoch 28/50
# 469/469 - 2s - loss: 0.0059 - accuracy: 0.9980 - val_loss: 0.0512 - val_accuracy: 0.9889 - 2s/epoch - 4ms/step
# Epoch 29/50
# 469/469 - 2s - loss: 0.0033 - accuracy: 0.9990 - val_loss: 0.0479 - val_accuracy: 0.9901 - 2s/epoch - 4ms/step
# Epoch 30/50
# 469/469 - 2s - loss: 0.0036 - accuracy: 0.9988 - val_loss: 0.0443 - val_accuracy: 0.9909 - 2s/epoch - 4ms/step
# Epoch 31/50
# 469/469 - 2s - loss: 0.0060 - accuracy: 0.9980 - val_loss: 0.0449 - val_accuracy: 0.9910 - 2s/epoch - 4ms/step
# Epoch 32/50
# 469/469 - 2s - loss: 0.0047 - accuracy: 0.9983 - val_loss: 0.0547 - val_accuracy: 0.9908 - 2s/epoch - 5ms/step
# Epoch 33/50
# 469/469 - 2s - loss: 0.0034 - accuracy: 0.9990 - val_loss: 0.0473 - val_accuracy: 0.9903 - 2s/epoch - 4ms/step
# Epoch 34/50
# 469/469 - 2s - loss: 0.0029 - accuracy: 0.9990 - val_loss: 0.0567 - val_accuracy: 0.9890 - 2s/epoch - 4ms/step
# Epoch 35/50
# 469/469 - 2s - loss: 0.0044 - accuracy: 0.9985 - val_loss: 0.0531 - val_accuracy: 0.9898 - 2s/epoch - 4ms/step
# Epoch 36/50
# 469/469 - 2s - loss: 0.0053 - accuracy: 0.9983 - val_loss: 0.0474 - val_accuracy: 0.9911 - 2s/epoch - 4ms/step
# Epoch 37/50
# 469/469 - 2s - loss: 0.0017 - accuracy: 0.9996 - val_loss: 0.0463 - val_accuracy: 0.9907 - 2s/epoch - 4ms/step
# Epoch 38/50
# 469/469 - 2s - loss: 0.0018 - accuracy: 0.9994 - val_loss: 0.0455 - val_accuracy: 0.9918 - 2s/epoch - 5ms/step
# Epoch 39/50
# 469/469 - 2s - loss: 0.0053 - accuracy: 0.9985 - val_loss: 0.0562 - val_accuracy: 0.9884 - 2s/epoch - 4ms/step
# Epoch 40/50
# 469/469 - 2s - loss: 0.0021 - accuracy: 0.9993 - val_loss: 0.0513 - val_accuracy: 0.9910 - 2s/epoch - 4ms/step
# Epoch 41/50
# 469/469 - 2s - loss: 0.0018 - accuracy: 0.9994 - val_loss: 0.0573 - val_accuracy: 0.9904 - 2s/epoch - 4ms/step
# Epoch 42/50
# 469/469 - 2s - loss: 0.0067 - accuracy: 0.9978 - val_loss: 0.0582 - val_accuracy: 0.9896 - 2s/epoch - 4ms/step
# Epoch 43/50
# 469/469 - 2s - loss: 0.0033 - accuracy: 0.9988 - val_loss: 0.0575 - val_accuracy: 0.9899 - 2s/epoch - 4ms/step
# Epoch 44/50
# 469/469 - 3s - loss: 9.2079e-04 - accuracy: 0.9997 - val_loss: 0.0462 - val_accuracy: 0.9915 - 3s/epoch - 5ms/step
# Epoch 45/50
# 469/469 - 2s - loss: 0.0018 - accuracy: 0.9994 - val_loss: 0.0494 - val_accuracy: 0.9913 - 2s/epoch - 4ms/step
# Epoch 46/50
# 469/469 - 2s - loss: 0.0066 - accuracy: 0.9981 - val_loss: 0.0540 - val_accuracy: 0.9896 - 2s/epoch - 4ms/step
# Epoch 47/50
# 469/469 - 2s - loss: 0.0017 - accuracy: 0.9995 - val_loss: 0.0574 - val_accuracy: 0.9900 - 2s/epoch - 4ms/step
# Epoch 48/50
# 469/469 - 2s - loss: 0.0029 - accuracy: 0.9991 - val_loss: 0.0581 - val_accuracy: 0.9907 - 2s/epoch - 4ms/step
# Epoch 49/50
# 469/469 - 2s - loss: 0.0028 - accuracy: 0.9991 - val_loss: 0.0600 - val_accuracy: 0.9907 - 2s/epoch - 4ms/step
# Epoch 50/50
# 469/469 - 2s - loss: 0.0014 - accuracy: 0.9995 - val_loss: 0.0585 - val_accuracy: 0.9908 - 2s/epoch - 5ms/step
# 정확도= 99.08000230789185
